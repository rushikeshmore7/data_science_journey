# %% [markdown]
# ### 1 Check whether a number is between 10 and 50.

# %%
num=34

if num>10 and num<50:
    print("number is between 10 to 50:",num)
# Out:
# number is between 10 to 50: 34

# %% [markdown]
# ### 2 Check whether a student passed (marks ≥ 35).

# %%
marks=40

if marks>=35 and marks<100:
    print("student is pass:",marks)
# Out:
# student is pass: 40

# %% [markdown]
# ### 3 Check whether age is between 18 and 60.

# %%
age=55
if age>=18 and age<60:
    print("eligibality criteria is match")
# Out:
# eligibality criteria is match

# %% [markdown]
# ### 4 Check whether both username and password are correct.

# %%
user="rushi@123"
passw=1234

if user=="rushi@123" and passw==1234:
    print("login successfull !")
# Out:
# login successfull !

# %% [markdown]
# ### 5 Check whether either of two numbers is positive.

# %%
num1=2
num2=1

if num1>0 and num2>0:
    print("both number are positive")

else:
    print("number are not positive")
# Out:
# both number are positive

# %% [markdown]
# ### 6 Use not to reverse a Boolean value.

# %%
name_1=False
print(not name_1)
# Out:
# True

# %% [markdown]
# ### 7 Check whether a year is a leap year.

# %%
year = int(input("Enter year: "))

if year % 400 == 0:
    
   
    elif year % 4 == 0:
    
else:
# Out:
#   Cell In[22], line 6
#     elif year % 4 == 0:
#     ^
# SyntaxError: invalid syntax

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    print(year, "is a Leap Year")
elif year % 100 == 0:
    print(year, "is not a Leap Year")
elif year % 4 == 0:
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter a year:  2000
# 2000 is a Leap Year
