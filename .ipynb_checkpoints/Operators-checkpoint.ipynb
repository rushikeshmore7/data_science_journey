# %% [markdown]
# ### 1. Write a program to add two numbers.

# %%
a=7
b=7
sum=a+b
print(sum)
# Out:
# 14

# %% [markdown]
# ### 2. Subtract two numbers.

# %%
a=6
b=4
sub=a-b
print(sub)
# Out:
# 2

# %% [markdown]
# ### 3.Multiply two numbers.

# %%
a=4
b=6
mul=a*b
print(mul)
# Out:
# 24

# %% [markdown]
# ### 4.Divide two numbers using /.

# %%
a=12
b=10
div=a/b
print(div)
# Out:
# 1.2

# %% [markdown]
# ### 5.Find floor division //.

# %%
a=10
b=6
floor=a//b
print(floor)
# Out:
# 1

# %% [markdown]
# ### 6.Find the remainder using %.

# %%
a=24
b=10
rem=a%b
print(rem)
# Out:
# 4

# %% [markdown]
# ### 7.Calculate the power of a number using***.

# %%
a=2
b=3
powe=a**b
print(powe)
# Out:
# 8

# %% [markdown]
# ### 8. Find the square of a number.

# %%
a=2
b=2
squ=a*b
print(squ)
# Out:
# 4

# %% [markdown]
# ### 9.Find the cube of a number.

# %%
a=2
b=3
cub=a**b
print(cub)
# Out:
# 8

# %% [markdown]
# ### 10.Calculate (a+b)*c.

# %%
a=10
b=4
c=2
calc=(a+b)*c
print(calc)
# Out:
# 28

# %% [markdown]
# ### 11.Find the average of three numbrs.

# %%
a=10
b=30
c=40
avg=(a+b+c)/3
print(avg)
# Out:
# 17.333333333333332

# %% [markdown]
# ### 12.Find the area of a rectangle.

# %%
length=20
width=18
area=length*width
print(area)
# Out:
# 360

# %% [markdown]
# ### 13.Find the area of a circle

# %%
area=3.14* 5**2
print(area)
# Out:
# 78.5

# %% [markdown]
# ### 14.Convert days into weeks and remaining days using // and %.

# %%
days=100
days_weak=7
weeks=100//7
remain=days%7
print(remain)
print(weeks)
# Out:
# 2
# 14

# %% [markdown]
# ### 15.Convert seconds into hours, minutes, and seconds.

# %%
total_seconds = 3665

hours = total_seconds // 3600
remaining_seconds = total_seconds % 3600

minutes = remaining_seconds // 60
seconds = remaining_seconds % 60

print("Hours:", hours)
print("Minutes:", minutes)
print("Seconds:", seconds)
# Out:
# Hours: 1
# Minutes: 1
# Seconds: 5

# %% [markdown]
# ### 16.Find whether a number is even or odd using % .

# %%
a=2,4,5,7,8
num=2%2
num1=4%2
num2=5%2
num3=7%2
num4=8%2
print(num)  #Even
print(num1) #Even
print(num2) #odd
print(num3) #odd
print(num4) #Even
# Out:
# 0
# 0
# 1
# 1
# 0

# %% [markdown]
# ### 17.Reverse a two-digit number using % and //.

# %%
number = 24

last = number % 10
first = number // 10

reverse = (last * 10) 

print("Original Number:", number)
print("Reversed Number:", reverse)
# Out:
# Original Number: 24
# Reversed Number: 42

# %% [markdown]
# ### 18.Find the last digit of a number

# %%
number=124
last=number%10
print("last number is :",last)
# Out:
# last number is : 4

# %% [markdown]
# ### 19. Remove the last digit using //.

# %%
num=44
remove=num//10
print("last digit is removed:",remove)
# Out:
# last digit is removed: 4

# %% [markdown]
# ### 20. Find the sum of digits of a three-digit number

# %%
A=10
B=30
C=20

sum=A+B+C
print(sum)
# Out:
# 60
